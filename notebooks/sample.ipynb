# %%
import pandas as pd
from certa.explain import CertaExplainer
from certa.utils import merge_sources
from certa.models.utils import from_type

# %%
dataset = 'abt_buy'
model_type = 'dm'
model = from_type(model_type)
model.load('/path/to/dm_model.pth')

# %%
def predict_fn(x):
    return model.predict(x)

# %%
datadir = '/path/to/dataset_dir'
lsource = pd.read_csv(datadir + '/tableA.csv')
rsource = pd.read_csv(datadir + '/tableB.csv')
gt = pd.read_csv(datadir + '/train.csv')
valid = pd.read_csv(datadir + '/valid.csv')
test = pd.read_csv(datadir + '/test.csv')

# %%
test_df = merge_sources(test, 'ltable_', 'rtable_', lsource, rsource, ['label'], [])

# %%
idx = 27
rand_row = test_df.iloc[idx]
l_id = int(rand_row['ltable_id'])
l_tuple = lsource.iloc[l_id]
r_id = int(rand_row['rtable_id'])
r_tuple = rsource.iloc[r_id]
rand_row.head()
# Out:
# label                                                                 0
# ltable_description    samsung 46 ' series 5 lcd black flat panel hdt...
# ltable_id                                                           572
# ltable_name           samsung 46 ' series 5 lcd black flat panel hdt...
# ltable_price                                                        NaN
# Name: 27, dtype: object

# %%
l_tuple
# Out:
# id                                                           572
# name           samsung 46 ' series 5 lcd black flat panel hdt...
# description    samsung 46 ' series 5 lcd black flat panel hdt...
# price                                                        NaN
# Name: 572, dtype: object

# %%
r_tuple
# Out:
# id                                                           695
# name                       samsung 4 series ln22a450 22 ' lcd tv
# description    samsung ln22a450 22 ' widescreen 720p lcd hdtv...
# price                                                     397.77
# Name: 695, dtype: object

# %%
certa_explainer = CertaExplainer(lsource, rsource)
saliency_df, cf_summary, counterfactual_examples, triangles, lattices = certa_explainer.explain(l_tuple, r_tuple, predict_fn)

# %%
saliency_df.to_dict()
# Out:
# {'ltable_name': {0: 0.0625},
#  'ltable_description': {0: 0.0325},
#  'ltable_price': {0: 0.0325},
#  'rtable_name': {0: 0.0225},
#  'rtable_description': {0: 0.0125},
#  'rtable_price': {0: 0.0125}}

# %%
counterfactual_examples
# Out:
#                                           ltable_name  \
# 0                                              lcd tv
# 22                       samsung 4 series ln22a450 22
# 21                       samsung 4 series ln22a450 22
# 20                       samsung 4 series ln22a450 22
# 26  samsung 46 ' series 5 lcd black flat panel hdt...
# 18    samsung 22 ' black flat panel lcd hdtv ln22a450
# 17    samsung 22 ' black flat panel lcd hdtv ln22a450
# 16    samsung 22 ' black flat panel lcd hdtv ln22a450
# 30  samsung 46 ' series 5 lcd black flat panel hdt...
# 14                               ln22a450 22 ' lcd tv
# 13                               ln22a450 22 ' lcd tv
# 25  samsung 46 ' series 5 lcd black flat panel hdt...
# 12                               ln22a450 22 ' lcd tv
# 10                        series ln22a450 22 ' lcd tv
# 9                         series ln22a450 22 ' lcd tv
# 8                         series ln22a450 22 ' lcd tv
# 28  samsung 46 ' series 5 lcd black flat panel hdt...
# 6                                            ' lcd tv
# 5                                            ' lcd tv
# 4                                            ' lcd tv
# 29  samsung 46 ' series 5 lcd black flat panel hdt...
# 2                                              lcd tv
# 1                                              lcd tv
# 24  samsung 46 ' series 5 lcd black flat panel hdt...
# 27  samsung 46 ' series 5 lcd black flat panel hdt...
# 15                               ln22a450 22 ' lcd tv
# 19    samsung 22 ' black flat panel lcd hdtv ln22a450
# 11                        series ln22a450 22 ' lcd tv
# 7                                            ' lcd tv
# 3                                              lcd tv
# 23                       samsung 4 series ln22a450 22
# 31  samsung 46 ' series 5 lcd black flat panel hdt...
#
#                                    ltable_description  ltable_price  \
# 0   samsung 46 ' series 5 lcd black flat panel hdt...           NaN
#
samsung ln22a450 22 ' widescreen 720p lcd hdtv...        397.77
# 10  samsung ln22a450 22 ' widescreen 720p lcd hdtv...        397.77
# 9   samsung ln22a450 22 ' widescreen 720p lcd hdtv...        397.77
# 8   samsung ln22a450 22 ' widescreen 720p lcd hdtv...        397.77
# 28  samsung ln22a450 22 ' widescreen 720p lcd hdtv...        397.77
# 6   samsung ln22a450 22 ' widescreen 720p lcd hdtv...        397.77
# 5   samsung ln22a450 22 ' widescreen 720p lcd hdtv...        397.77
# 4   samsung ln22a450 22 ' widescreen 720p lcd hdtv...        397.77
# 29  samsung ln46a550 46 ' widescreen 1080p lcd hdt...        397.77
# 2   samsung ln22a450 22 ' widescreen 720p lcd hdtv...        397.77
# 1   samsung ln22a450 22 ' widescreen 720p lcd hdtv...        397.77
# 24  samsung ln22a450 22 ' widescreen 720p lcd hdtv...        397.77
# 27  samsung ln46a550 46 ' widescreen 1080p lcd hdt...       1143.99
# 15  samsung ln22a450 22 ' widescreen 720p lcd hdtv...        397.77
# 19  samsung ln22a450 22 ' widescreen 720p lcd hdtv...        397.77
# 11  samsung ln22a450 22 ' widescreen 720p lcd hdtv...        397.77
# 7   samsung ln22a450 22 ' widescreen 720p lcd hdtv...        397.77
# 3   samsung ln22a450 22 ' widescreen 720p lcd hdtv...        397.77
# 23  samsung ln22a450 22 ' widescreen 720p lcd hdtv...        397.77
# 31  samsung ln46a550 46 ' widescreen 1080p lcd hdt...       1143.99
#
#                                   alteredAttributes  \
# 0                                    (ltable_name,)
# 22                      (ltable_name, ltable_price)
# 21                (ltable_name, ltable_description)
# 20                                   (ltable_name,)
# 26                      (rtable_name, rtable_price)
# 18                      (ltable_name, ltable_price)
# 17                (ltable_name, ltable_description)
# 16                                   (ltable_name,)
# 30                      (rtable_name, rtable_price)
# 14                      (ltable_name, ltable_price)
# 13                (ltable_name, ltable_description)
# 25                (rtable_name, rtable_description)
# 12                                   (ltable_name,)
# 10                      (ltable_name, ltable_price)
# 9                 (ltable_name, ltable_description)
# 8                                    (ltable_name,)
# 28                                   (rtable_name,)
# 6                       (ltable_name, ltable_price)
# 5                 (ltable_name, ltable_description)
# 4                                    (ltable_name,)
# 29                (rtable_name, rtable_description)
# 2                       (ltable_name, ltable_price)
# 1                 (ltable_name, ltable_description)
# 24                                   (rtable_name,)
# 27  (rtable_name, rtable_description, rtable_price)
# 15  (ltable_name, ltable_description, ltable_price)
# 19  (ltable_name, ltable_description, ltable_price)
# 11  (ltable_name, ltable_description, ltable_price)
# 7   (ltable_name, ltable_description, ltable_price)
# 3   (ltable_name, ltable_description, ltable_price)
# 23  (ltable_name, ltable_description, ltable_price)
# 31  (rtable_name, rtable_description, rtable_price)
#
#                                         droppedValues  \
# 0   [samsung 46 ' series 5 lcd black flat panel hd...
# 22  [samsung 46 ' series 5 lcd black flat panel hd...
# 21  [samsung 46 ' series 5 lcd black flat panel hd...
# 20  [samsung 46 ' series 5 lcd black flat panel hd...
# 26    [samsung 4 series ln22a450 22 ' lcd tv, 397.77]
# 18  [samsung 46 ' series 5 lcd black flat panel hd...
# 17  [samsung 46 ' series 5 lcd black flat panel hd...
# 16  [samsung 46 ' series 5 lcd black flat panel hd...
# 30    [samsung 4 series ln22a450 22 ' lcd tv, 397.77]
# 14  [samsung 46 ' series 5 lcd black flat panel hd...
# 13  [samsung 46 ' series 5 lcd black flat panel hd...
# 25  [samsung 4 series ln22a450 22 ' lcd tv, samsun...
# 12  [samsung 46 ' series 5 lcd black flat panel hd...
# 10  [samsung 46 ' series 5 lcd black flat panel hd...
# 9   [samsung 46 ' series 5 lcd black flat panel hd...
# 8   [samsung 46 ' series 5 lcd black flat panel hd...
# 28            [samsung 4 series ln22a450 22 ' lcd tv]
# 6   [samsung 46 ' series 5 lcd black flat panel hd...
# 5   [samsung 46 ' series 5 lcd black flat panel hd...
# 4   [samsung 46 ' series 5 lcd black flat panel hd...
# 29  [samsung 4 series ln22a450 22 ' lcd tv, samsun...
# 2   [samsung 46 ' series 5 lcd black flat panel hd...
# 1   [samsung 46 ' series 5 lcd black flat panel hd...
# 24            [samsung 4 series ln22a450 22 ' lcd tv]
# 27  [samsung 4 series ln22a450 22 ' lcd tv, samsun...
# 15  [samsung 46 ' series 5 lcd black flat panel hd...
# 19  [samsung 46 ' series 5 lcd black flat panel hd...
# 11  [samsung 46 ' series 5 lcd black flat panel hd...
# 7   [samsung 46 ' series 5 lcd black flat panel hd...
# 3   [samsung 46 ' series 5 lcd black flat panel hd...
# 23  [samsung 46 ' series 5 lcd black flat panel hd...
# 31  [samsung 4 series ln22a450 22 ' lcd tv, samsun...
#
#                                          copiedValues  nomatch_score  \
# 0                                            [lcd tv]       0.065987
# 22             [samsung 4 series ln22a450 22, 397.77]       0.116304
# 21  [samsung 4 series ln22a450 22, samsung ln22a45...       0.111736
# 20                     [samsung 4 series ln22a450 22]       0.124058
# 26            [samsung ln46a550 46 ' lcd tv, 1143.99]       0.061806
# 18  [samsung 22 ' black flat panel lcd hdtv ln22a4...       0.262956
# 17  [samsung 22 ' black flat panel lcd hdtv ln22a4...       0.272071
# 16  [samsung 22 ' black flat panel lcd hdtv ln22a450]       0.262956
# 30            [samsung ln46a550 46 ' lcd tv, 1143.99]       0.061806
# 14                     [ln22a450 22 ' lcd tv, 397.77]       0.060760
# 13  [ln22a450 22 ' lcd tv, samsung ln22a450 22 ' w...       0.059131
# 25  [samsung ln46a550 46 ' lcd tv, samsung ln46a55...       0.059300
# 12                             [ln22a450 22 ' lcd tv]       0.061933
# 10              [series ln22a450 22 ' lcd tv, 397.77]       0.059832
# 9   [series ln22a450 22 ' lcd tv, samsung ln22a450...       0.058230
# 8                       [series ln22a450 22 ' lcd tv]       0.061397
# 28                     [samsung ln46a550 46 ' lcd tv]       0.059815
# 6                                  [' lcd tv, 397.77]       0.064568
# 5   [' lcd tv, samsung ln22a450 22 ' widescreen 72...       0.062846
# 4                                          [' lcd tv]       0.065935
# 29  [samsung ln46a550 46 ' lcd tv, samsung ln46a55...       0.059300
# 2                                    [lcd tv, 397.77]       0.064623
# 1   [lcd tv, samsung ln22a450 22 ' widescreen 720p...       0.062905
# 24                     [samsung ln46a550 46 ' lcd tv]       0.059755
# 27  [samsung ln46a550 46 ' lcd tv, samsung ln46a55...       0.061266
# 15  [ln22a450 22 ' lcd tv, samsung ln22a450 22 ' w...       0.057687
# 19  [samsung 22 ' black flat panel lcd hdtv ln22a4...       0.272071
# 11  [series ln22a450 22 ' lcd tv, samsung ln22a450...       0.056802
# 7   [' lcd tv, samsung ln22a450 22 ' widescreen 72...       0.061348
# 3   [lcd tv, samsung ln22a450 22 ' widescreen 720p...       0.061404
# 23  [samsung 4 series ln22a450 22, samsung ln22a45...       0.104824
# 31  [samsung ln46a550 46 ' lcd tv, samsung ln46a55...       0.061266
#
#     match_score  attr_count
# 0      0.934013           2
# 22     0.883696           2
# 21     0.888264           2
# 20     0.875942           2
# 26     0.938194           2
# 18     0.737044           2
# 17     0.727929           2
# 16     0.737044           2
# 30     0.938194           2
# 14     0.939240           2
# 13     0.940869           2
# 25     0.940700           2
# 12     0.938067           2
# 10     0.940168           2
# 9      0.941770           2
# 8      0.938603           2
# 28     0.940185           2
# 6      0.935432           2
# 5      0.937154           2
# 4      0.934065           2
# 29     0.940700           2
# 2      0.935377           2
# 1      0.937095           2
# 24     0.940245           2
# 27     0.938734           3
# 15     0.942313           3
# 19     0.727929           3
# 11     0.943198           3
# 7      0.938652           3
# 3      0.938596           3
# 23     0.895176           3
# 31     0.938734           3
